# %%
from nltk.tokenize import sent_tokenize,word_tokenize
import string

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
example_text = """16/09/2004 Set in Varanasi, Gopal, Aarti and Raghav have been best friends since school. As teenagers, Gopal has fallen in love with Aarti, often pushing to be more than friends. Aarti consistently rebuffs, expressing that she values their friendship and isn't ready for a relationship with anybody.

Gopal and Raghav are both studying to get into engineering colleges, but Gopal gets a low rank in the All India Engineering Entrance Exams, while Raghav is among the toppers. To help improve his rank, Gopal moves to Kota alone to join reputed coaching classes to resit the exam the following year. Raghav goes on to pass the IIT entrance exam as well, and starts attending Banaras Hindu University.

During Gopal's absence in Kota, Aarti and Raghav develop feelings for each other, and Aarti tells Gopal about her relationship when they chat online. Gopal is heartbroken and lashes out at her, causing them to lose touch briefly and Gopal to fall behind in his course. When they rekindle their friendship, Gopal begins to study hard again, but gets a low rank once more after sitting the AIEEE exam for the second time. Gopal returns home to Varanasi, where his father dies shortly after learning of his low rank. Meanwhile, Raghav and Aarti's relationship is flourishing, and Raghav has found his passion in activism and being on his university's newspaper committee.
"""

# %%
sentences = sent_tokenize(example_text)
sentences_as_words = [word_tokenize(sentence) for sentence in sentences]
sentences_without_punctuations_as_words = [[word for word in word_tokenize(sentence) if word not in string.punctuation] for sentence in sentences]
# sentences_without_punctuations_as_words2 = [[word for word in word_tokenize(sentence) if word.isalnum()] for sentence in sentences]
words_with_punctuation = word_tokenize(example_text)
words_no_punctuation = [word for word in words_with_punctuation if word not in string.punctuation]
# words_no_punctuation = [word for word in words_with_punctuation if word.isalnum()]

# %%
sentences
# Out:
# ['16/09/2004 Set in Varanasi, Gopal, Aarti and Raghav have been best friends since school.',
#  'As teenagers, Gopal has fallen in love with Aarti, often pushing to be more than friends.',
#  "Aarti consistently rebuffs, expressing that she values their friendship and isn't ready for a relationship with anybody.",
#  'Gopal and Raghav are both studying to get into engineering colleges, but Gopal gets a low rank in the All India Engineering Entrance Exams, while Raghav is among the toppers.',
#  'To help improve his rank, Gopal moves to Kota alone to join reputed coaching classes to resit the exam the following year.',
#  'Raghav goes on to pass the IIT entrance exam as well, and starts attending Banaras Hindu University.',
#  "During Gopal's absence in Kota, Aarti and Raghav develop feelings for each other, and Aarti tells Gopal about her relationship when they chat online.",
#  'Gopal is heartbroken and lashes out at her, causing them to lose touch briefly and Gopal to fall behind in his course.',
#  'When they rekindle their friendship, Gopal begins to study hard again, but gets a low rank once more after sitting the AIEEE exam for the second time.',
#  'Gopal returns home to Varanasi, where his father dies shortly after learning of his low rank.',
#  "Meanwhile, Raghav and Aarti's relationship is flourishing, and Raghav has found his passion in activism and being on his university's newspaper committee."]

# %%
sentences_as_words
# Out:
# [['16/09/2004',
#   'Set',
#   'in',
#   'Varanasi',
#   ',',
#   'Gopal',
#   ',',
#   'Aarti',
#   'and',
#   'Raghav',
#   'have',
#   'been',
#   'best',
#   'friends',
#   'since',
#   'school',
#   '.'],
#  ['As',
#   'teenagers',
#   ',',
#   'Gopal',
#   'has',
#   'fallen',
#   'in',
#   'love',
#   'with',
#   'Aarti',
#   ',',
#   'often',
#   'pushing',
#   'to',
#   'be',
#   'more',
#   'than',
#   'friends',
#   '.'],
#  ['Aarti',
#   'consistently',
#   'rebuffs',
#   ',',
#   'expressing',
#   'that',
#   'she',
#   'values',
#   'their',
#   'friendship',
#   'and',
#   'is',
#   "n't",
#   'ready',
#   'for',
#   'a',
#   'relationship',
#   'with',
#   'anybody',
#   '.'],
#  ['Gopal',
#   'and',
#   'Raghav',
#   'are',
#   'both',
#   'studying',
#   'to',
#   'get',
#   'into',
#   'engineering',
#   'colleges',
#   ',',
#   'but',
#   'Gopal',
#   'gets',
#   'a',
#   'low',
#   'rank',
#   'in',
#   'the',
#   'All',
#   'India',
#   'Engineering',
#   'Entrance',
#   'Exams',
#   ',',
#   'while',
#   'Raghav',
#   'is',
#   'among',
#   'the',
#   'toppers',
#   '.'],
#  ['To',
#   'help',
#   'improve',
#   'his',
#   'rank',
#   ',',
#   'Gopal',
#   'moves',
#   'to',
#   'Kota',
#   'alone',
#   'to',
#   'join',
#   'reputed',
#   'coaching',
#   'classes',
#   'to',
#   'resit',
#   'the',
#   'exam',
#   'the',
#   'following',
#   'year',
#   '.'],
#  ['Raghav',
#   'goes',
#   'on',
#   'to',
#   'pass',
#   'the',
#   'IIT',
#   'entrance',
#   'exam',
#   'as',
#   'well',
#   ',',
#   'and',
#   'starts',
#   'attending',
#   'Banaras',
#   'Hindu',
#   'University',
#   '.'],
#  ['During',
#   'Gopal',
#   "'s",
#   'absence',
#   'in',
#   'Kota',
#   ',',
#   'Aarti',
#   'and',
#   'Raghav',
#   'develop',
#   'feelings',
#   'for',
#   'each',
#   'other',
#   ',',
#   'and',
#   'Aarti',
#   'tells',
#   'Gopal',
#   'about',
#   'her',
#   'relationship',
#   'when',
#   'they',
#   'chat',
#   'online',
#   '.'],
#  ['Gopal',
#   'is',
#   'heartbroken',
#   'and',
#   'lashes',
#   'out',
#   'at',
#   'her',
#   ',',
#   'causing',
#   'them',
#   'to',
#   'lose',
#   'touch',
#   'briefly',
#   'and',
#   'Gopal',
#   'to',
#   'fall',
#   'behind',
#   'in',
#   'his',
#   'course',
#   '.'],
#  ['When',
#   'they',
#   'rekindle',
#   'their',
#   'friendship',
#   ',',
#   'Gopal',
#   'begins',
#   'to',
#   'study',
#   'hard',
#   'again',
#   ',',
#   'but',
#   'gets',
#   'a',
#   'low',
#   'rank',
#   'once',
#   'more',
#   'after',
#   'sitting',
#   'the',
#   'AIEEE',
#   'exam',
#   'for',
#   'the',
#   'second',
#   'time',
#   '.'],
#  ['Gopal',
#   'returns',
#   'home',
#   'to',
#   'Varanasi',
#   ',',
#   'where',
#   'his',
#   'father',
#   'dies',
#   'shortly',
#   'after',
#   'learning',
#   'of',
#   'his',
#   'low',
#   'rank',
#   '.'],
#  ['Meanwhile',
#   ',',
#   'Raghav',
#   'and',
#   'Aarti',
#   "'s",
#   'relationship',
#   'is',
#   'flourishing',
#   ',',
#   'and',
#   'Raghav',
#   'has',
#   'found',
#   'his',
#   'passion',
#   'in',
#   'activism',
#   'and',
#   'being',
#   'on',
#   'his',
#   'university',
#   "'s",
#   'newspaper',
#   'committee',
#   '.']]

# %%
words_with_punctuation
# Out:
# ['16/09/2004',
#  'Set',
#  'in',
#  'Varanasi',
#  ',',
#  'Gopal',
#  ',',
#  'Aarti',
#  'and',
#  'Raghav',
#  'have',
#  'been',
#  'best',
#  'friends',
#  'since',
#  'school',
#  '.',
#  'As',
#  'teenagers',
#  ',',
#  'Gopal',
#  'has',
#  'fallen',
#  'in',
#  'love',
#  'with',
#  'Aarti',
#  ',',
#  'often',
#  'pushing',
#  'to',
#  'be',
#  'more',
#  'than',
#  'friends',
#  '.',
#  'Aarti',
#  'consistently',
#  'rebuffs',
#  ',',
#  'expressing',
#  'that',
#  'she',
#  'values',
#  'their',
#  'friendship',
#  'and',
#  'is',
#  "n't",
#  'ready',
#  'for',
#  'a',
#  'relationship',
#  'with',
#  'anybody',
#  '.',
#  'Gopal',
#  'and',
#  'Raghav',
#  'are',
#  'both',
#  'studying',
#  'to',
#  'get',
#  'into',
#  'engineering',
#  'colleges',
#  ',',
#  'but',
#  'Gopal',
#  'gets',
#  'a',
#  'low',
#  'rank',
#  'in',
#  'the',
#  'All',
#  'India',
#  'Engineering',
#  'Entrance',
#  'Exams',
#  ',',
#  'while',
#  'Raghav',
#  'is',
#  'among',
#  'the',
#  'toppers',
#  '.',
#  'To',
#  'help',
#  'improve',
#  'his',
#  'rank',
#  ',',
#  'Gopal',
#  'moves',
#  'to',
#  'Kota',
#  'alone',
#  'to',
#  'join',
#  'reputed',
#  'coaching',
#  'classes',
#  'to',
#  'resit',
#  'the',
#  'exam',
#  'the',
#  'following',
#  'year',
#  '.',
#  'Raghav',
#  'goes',
#  'on',
#  'to',
#  'pass',
#  'the',
#  'IIT',
#  'entrance',
#  'exam',
#  'as',
#  'well',
#  ',',
#  'and',
#  'starts',
#  'attending',
#  'Banaras',
#  'Hindu',
#  'University',
#  '.',
#  'During',
#  'Gopal',
#  "'s",
#  'absence',
#  'in',
#  'Kota',
#  ',',
#  'Aarti',
#  'and',
#  'Raghav',
#  'develop',
#  'feelings',
#  'for',
#  'each',
#  'other',
#  ',',
#  'and',
#  'Aarti',
#  'tells',
#  'Gopal',
#  'about',
#  'her',
#  'relationship',
#  'when',
#  'they',
#  'chat',
#  'online',
#  '.',
#  'Gopal',
#  'is',
#  'heartbroken',
#  'and',
#  'lashes',
#  'out',
#  'at',
#  'her',
#  ',',
#  'causing',
#  'them',
#  'to',
#  'lose',
#  'touch',
#  'briefly',
#  'and',
#  'Gopal',
#  'to',
#  'fall',
#  'behind',
#  'in',
#  'his',
#  'course',
#  '.',
#  'When',
#  'they',
#  'rekindle',
#  'their',
#  'friendship',
#  ',',
#  'Gopal',
#  'begins',
#  'to',
#  'study',
#  'hard',
#  'again',
#  ',',
#  'but',
#  'gets',
#  'a',
#  'low',
#  'rank',
#  'once',
#  'more',
#  'after',
#  'sitting',
#  'the',
#  'AIEEE',
#  'exam',
#  'for',
#  'the',
#  'second',
#  'time',
#  '.',
#  'Gopal',
#  'returns',
#  'home',
#  'to',
#  'Varanasi',
#  ',',
#  'where',
#  'his',
#  'father',
#  'dies',
#  'shortly',
#  'after',
#  'learning',
#  'of',
#  'his',
#  'low',
#  'rank',
#  '.',
#  'Meanwhile',
#  ',',
#  'Raghav',
#  'and',
#  'Aarti',
#  "'s",
#  'relationship',
#  'is',
#  'flourishing',
#  ',',
#  'and',
#  'Raghav',
#  'has',
#  'found',
#  'his',
#  'passion',
#  'in',
#  'activism',
#  'and',
#  'being',
#  'on',
#  'his',
#  'university',
#  "'s",
#  'newspaper',
#  'committee',
#  '.']

# %%
sentences_without_punctuations_as_words
# Out:
# [['16/09/2004',
#   'Set',
#   'in',
#   'Varanasi',
#   'Gopal',
#   'Aarti',
#   'and',
#   'Raghav',
#   'have',
#   'been',
#   'best',
#   'friends',
#   'since',
#   'school'],
#  ['As',
#   'teenagers',
#   'Gopal',
#   'has',
#   'fallen',
#   'in',
#   'love',
#   'with',
#   'Aarti',
#   'often',
#   'pushing',
#   'to',
#   'be',
#   'more',
#   'than',
#   'friends'],
#  ['Aarti',
#   'consistently',
#   'rebuffs',
#   'expressing',
#   'that',
#   'she',
#   'values',
#   'their',
#   'friendship',
#   'and',
#   'is',
#   "n't",
#   'ready',
#   'for',
#   'a',
#   'relationship',
#   'with',
#   'anybody'],
#  ['Gopal',
#   'and',
#   'Raghav',
#   'are',
#   'both',
#   'studying',
#   'to',
#   'get',
#   'into',
#   'engineering',
#   'colleges',
#   'but',
#   'Gopal',
#   'gets',
#   'a',
#   'low',
#   'rank',
#   'in',
#   'the',
#   'All',
#   'India',
#   'Engineering',
#   'Entrance',
#   'Exams',
#   'while',
#   'Raghav',
#   'is',
#   'among',
#   'the',
#   'toppers'],
#  ['To',
#   'help',
#   'improve',
#   'his',
#   'rank',
#   'Gopal',
#   'moves',
#   'to',
#   'Kota',
#   'alone',
#   'to',
#   'join',
#   'reputed',
#   'coaching',
#   'classes',
#   'to',
#   'resit',
#   'the',
#   'exam',
#   'the',
#   'following',
#   'year'],
#  ['Raghav',
#   'goes',
#   'on',
#   'to',
#   'pass',
#   'the',
#   'IIT',
#   'entrance',
#   'exam',
#   'as',
#   'well',
#   'and',
#   'starts',
#   'attending',
#   'Banaras',
#   'Hindu',
#   'University'],
#  ['During',
#   'Gopal',
#   "'s",
#   'absence',
#   'in',
#   'Kota',
#   'Aarti',
#   'and',
#   'Raghav',
#   'develop',
#   'feelings',
#   'for',
#   'each',
#   'other',
#   'and',
#   'Aarti',
#   'tells',
#   'Gopal',
#   'about',
#   'her',
#   'relationship',
#   'when',
#   'they',
#   'chat',
#   'online'],
#  ['Gopal',
#   'is',
#   'heartbroken',
#   'and',
#   'lashes',
#   'out',
#   'at',
#   'her',
#   'causing',
#   'them',
#   'to',
#   'lose',
#   'touch',
#   'briefly',
#   'and',
#   'Gopal',
#   'to',
#   'fall',
#   'behind',
#   'in',
#   'his',
#   'course'],
#  ['When',
#   'they',
#   'rekindle',
#   'their',
#   'friendship',
#   'Gopal',
#   'begins',
#   'to',
#   'study',
#   'hard',
#   'again',
#   'but',
#   'gets',
#   'a',
#   'low',
#   'rank',
#   'once',
#   'more',
#   'after',
#   'sitting',
#   'the',
#   'AIEEE',
#   'exam',
#   'for',
#   'the',
#   'second',
#   'time'],
#  ['Gopal',
#   'returns',
#   'home',
#   'to',
#   'Varanasi',
#   'where',
#   'his',
#   'father',
#   'dies',
#   'shortly',
#   'after',
#   'learning',
#   'of',
#   'his',
#   'low',
#   'rank'],
#  ['Meanwhile',
#   'Raghav',
#   'and',
#   'Aarti',
#   "'s",
#   'relationship',
#   'is',
#   'flourishing',
#   'and',
#   'Raghav',
#   'has',
#   'found',
#   'his',
#   'passion',
#   'in',
#   'activism',
#   'and',
#   'being',
#   'on',
#   'his',
#   'university',
#   "'s",
#   'newspaper',
#   'committee']]

# %%
words_no_punctuation
# Out:
# ['16/09/2004',
#  'Set',
#  'in',
#  'Varanasi',
#  'Gopal',
#  'Aarti',
#  'and',
#  'Raghav',
#  'have',
#  'been',
#  'best',
#  'friends',
#  'since',
#  'school',
#  'As',
#  'teenagers',
#  'Gopal',
#  'has',
#  'fallen',
#  'in',
#  'love',
#  'with',
#  'Aarti',
#  'often',
#  'pushing',
#  'to',
#  'be',
#  'more',
#  'than',
#  'friends',
#  'Aarti',
#  'consistently',
#  'rebuffs',
#  'expressing',
#  'that',
#  'she',
#  'values',
#  'their',
#  'friendship',
#  'and',
#  'is',
#  "n't",
#  'ready',
#  'for',
#  'a',
#  'relationship',
#  'with',
#  'anybody',
#  'Gopal',
#  'and',
#  'Raghav',
#  'are',
#  'both',
#  'studying',
#  'to',
#  'get',
#  'into',
#  'engineering',
#  'colleges',
#  'but',
#  'Gopal',
#  'gets',
#  'a',
#  'low',
#  'rank',
#  'in',
#  'the',
#  'All',
#  'India',
#  'Engineering',
#  'Entrance',
#  'Exams',
#  'while',
#  'Raghav',
#  'is',
#  'among',
#  'the',
#  'toppers',
#  'To',
#  'help',
#  'improve',
#  'his',
#  'rank',
#  'Gopal',
#  'moves',
#  'to',
#  'Kota',
#  'alone',
#  'to',
#  'join',
#  'reputed',
#  'coaching',
#  'classes',
#  'to',
#  'resit',
#  'the',
#  'exam',
#  'the',
#  'following',
#  'year',
#  'Raghav',
#  'goes',
#  'on',
#  'to',
#  'pass',
#  'the',
#  'IIT',
#  'entrance',
#  'exam',
#  'as',
#  'well',
#  'and',
#  'starts',
#  'attending',
#  'Banaras',
#  'Hindu',
#  'University',
#  'During',
#  'Gopal',
#  "'s",
#  'absence',
#  'in',
#  'Kota',
#  'Aarti',
#  'and',
#  'Raghav',
#  'develop',
#  'feelings',
#  'for',
#  'each',
#  'other',
#  'and',
#  'Aarti',
#  'tells',
#  'Gopal',
#  'about',
#  'her',
#  'relationship',
#  'when',
#  'they',
#  'chat',
#  'online',
#  'Gopal',
#  'is',
#  'heartbroken',
#  'and',
#  'lashes',
#  'out',
#  'at',
#  'her',
#  'causing',
#  'them',
#  'to',
#  'lose',
#  'touch',
#  'briefly',
#  'and',
#  'Gopal',
#  'to',
#  'fall',
#  'behind',
#  'in',
#  'his',
#  'course',
#  'When',
#  'they',
#  'rekindle',
#  'their',
#  'friendship',
#  'Gopal',
#  'begins',
#  'to',
#  'study',
#  'hard',
#  'again',
#  'but',
#  'gets',
#  'a',
#  'low',
#  'rank',
#  'once',
#  'more',
#  'after',
#  'sitting',
#  'the',
#  'AIEEE',
#  'exam',
#  'for',
#  'the',
#  'second',
#  'time',
#  'Gopal',
#  'returns',
#  'home',
#  'to',
#  'Varanasi',
#  'where',
#  'his',
#  'father',
#  'dies',
#  'shortly',
#  'after',
#  'learning',
#  'of',
#  'his',
#  'low',
#  'rank',
#  'Meanwhile',
#  'Raghav',
#  'and',
#  'Aarti',
#  "'s",
#  'relationship',
#  'is',
#  'flourishing',
#  'and',
#  'Raghav',
#  'has',
#  'found',
#  'his',
#  'passion',
#  'in',
#  'activism',
#  'and',
#  'being',
#  'on',
#  'his',
#  'university',
#  "'s",
#  'newspaper',
#  'committee']
